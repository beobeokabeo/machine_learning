# %%
import pandas as pd

# %%
from pandas_datareader import data as pdr

# %%
df = pdr.get_data_yahoo('MSFT', '2018-01-01', '2019-01-01')

# %%
df.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2018-01-02  86.309998  85.500000  86.129997  85.949997  22483800.0  82.798996
# 2018-01-03  86.510002  85.970001  86.059998  86.349998  26061400.0  83.184326
# 2018-01-04  87.660004  86.570000  86.589996  87.110001  21912000.0  83.916473
# 2018-01-05  88.410004  87.430000  87.660004  88.190002  23407100.0  84.956886
# 2018-01-08  88.580002  87.599998  88.199997  88.279999  22113000.0  85.043571

# %%
import quandl

# %%
apple = quandl.get('WIKI/AAPL', start_date='2014-01-01', end_date='2016-01-01')

# %%
apple.describe()
# Out:
#              Open        High         Low       Close        Volume  \
# count  504.000000  504.000000  504.000000  504.000000  5.040000e+02
# mean   207.655886  209.401200  205.933348  207.720361  4.325065e+07
# std    181.295916  182.711415  180.209083  181.596856  2.529600e+07
# min     90.210000   90.700000   89.650000   90.280000  5.704900e+06
# 25%    108.965000  109.877500  107.357500  108.807500  2.884406e+07
# 50%    118.185000  119.275000  116.990000  118.627500  4.299648e+07
# 75%    130.005000  130.872500  128.962500  129.985000  5.569448e+07
# max    649.900000  651.260000  644.470000  647.350000  1.895606e+08
#
#        Ex-Dividend  Split Ratio   Adj. Open   Adj. High    Adj. Low  \
# count   504.000000   504.000000  504.000000  504.000000  504.000000
# mean      0.018472     1.011905  101.022717  101.910366  100.050240
# std       0.206401     0.267261   17.647335   17.778989   17.408633
# min       0.000000     1.000000   65.820564   66.664622   65.603901
# ...

# %%
import datetime

# %%
apple = pdr.get_data_yahoo('AAPL', start=datetime.datetime(2008,1,1), end=datetime.datetime(2020,4,4))

# %%
apple.describe()
# Out:
#               High          Low         Open        Close        Volume  \
# count  3086.000000  3086.000000  3086.000000  3086.000000  3.086000e+03
# mean    100.415268    98.483791    99.445580    99.485092  9.686620e+07
# std      67.598855    66.307359    66.883125    67.003746  8.693603e+07
# min      11.714286    11.171429    11.341429    11.171429  1.136200e+07
# 25%      47.663928    46.664644    47.139644    47.272499  3.387042e+07
# 50%      88.692856    86.692860    87.985001    87.746429  6.995640e+07
# 75%     140.107494   138.812504   139.352497   139.715000  1.276432e+08
# max     327.850006   323.350006   324.739990   327.200012  8.432424e+08
#
#          Adj Close
# count  3086.000000
# mean     93.456556
# std      67.377138
# min       9.671075
# 25%      40.923676
# 50%      76.832474
# 75%     133.364918
# max     326.316681

# %%
apple.to_csv('apple_02_04.csv')

# %%
download_apple = 'apple_02_04.csv'

# %%
apple['Change'] = apple.Open-apple.Close

# %%
apple.head()
# Out:
#                  High        Low       Open      Close       Volume  \
# Date
# 2008-01-02  28.608572  27.507143  28.467142  27.834286  269794700.0
# 2008-01-03  28.198572  27.527143  27.915714  27.847143  210516600.0
# 2008-01-04  27.571428  25.555714  27.350000  25.721428  363958000.0
# 2008-01-07  26.228571  24.318571  25.892857  25.377142  518048300.0
# 2008-01-08  26.065714  24.400000  25.734285  24.464285  380954000.0
#
#             Adj Close    Change
# Date
# 2008-01-02  24.096073  0.632856
# 2008-01-03  24.107191  0.068571
# 2008-01-04  22.266973  1.628572
# 2008-01-07  21.968927  0.515715
# 2008-01-08  21.178667  1.270000

# %%
apple['Pct_Chg'] = apple.Change/apple.Open

# %%
apple.head()
# Out:
#                  High        Low       Open      Close       Volume  \
# Date
# 2008-01-02  28.608572  27.507143  28.467142  27.834286  269794700.0
# 2008-01-03  28.198572  27.527143  27.915714  27.847143  210516600.0
# 2008-01-04  27.571428  25.555714  27.350000  25.721428  363958000.0
# 2008-01-07  26.228571  24.318571  25.892857  25.377142  518048300.0
# 2008-01-08  26.065714  24.400000  25.734285  24.464285  380954000.0
#
#             Adj Close    Change   Pct_Chg
# Date
# 2008-01-02  24.096073  0.632856  0.022231
# 2008-01-03  24.107191  0.068571  0.002456
# 2008-01-04  22.266973  1.628572  0.059546
# 2008-01-07  21.968927  0.515715  0.019917
# 2008-01-08  21.178667  1.270000  0.049351

# %%
import matplotlib.pyplot as plt

# %%
apple['Pct_Chg'].plot(grid=True)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
def get(tickers, startdate, enddate):
    def data(ticker):
        return(pdr.get_data_yahoo(tickers, start=startdate, end=enddate))
    datas=map(data,tickers)
    return(pd.concat(datas,keys=tickers, names=['Ticker', 'Date']))

tickers=['MSFT', 'CRM', 'GE', 'MMM']
all_data=get(tickers, datetime.datetime(2015,1,1), datetime.datetime(2020,4,4))

# %%
all_data
# Out:
# Attributes          Adj Close                                          Close  \
# Symbols                  MSFT         CRM         GE         MMM        MSFT
# Ticker Date
# MSFT   2015-01-02   41.748566   59.240002  20.674500  140.665863   46.759998
#        2015-01-05   41.364658   58.169998  20.295000  137.493500   46.330002
#        2015-01-06   40.757530   57.200001  19.857750  136.027313   45.650002
#        2015-01-07   41.275364   56.930000  19.866001  137.013367   46.230000
#        2015-01-08   42.489609   58.590000  20.105247  140.297195   47.590000
# ...                       ...         ...        ...         ...         ...
# MMM    2020-03-30  159.784988  149.850006   7.878188  136.387268  160.229996
#        2020-03-31  157.271988  143.979996   7.928113  135.169342  157.710007
#        2020-04-01  151.687546  134.059998   7.029461  131.832443  152.110001
#        2020-04-02  154.828781  134.320007   6.889670  136.555603  155.259995
# ...

# %%
all_data.to_csv('all_data.csv')
